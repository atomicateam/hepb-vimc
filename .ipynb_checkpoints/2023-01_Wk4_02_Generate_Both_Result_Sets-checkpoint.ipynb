# %%
import numpy as np
import pandas as pd
import atomica as at

# %% [markdown]
# ## Input Functions

# %%
def load_cen_project(fw = 'hbv_v14_gamma_2.xlsx', db = "AFR_db_v1_2_1.xlsx", cl = 'AFR_calib_v1_2.xlsx'):
    ## Load projects and input parameters
    P =at.Project(framework=fw, databook=db, sim_start=1990, sim_end=2101, sim_dt=0.25, do_run=False) #test PSA on some parameters (vax eff, mtct_infx, mortality rates)

    cal = P.make_parset()
    cal.load_calibration(cl)

    res = P.run_sim(parset=cal, result_name = 'Status Quo')
    
    return P, res

# %%
def load_sto_project(n_samples, fw = 'hbv_v14_gamma_2.xlsx', db = "AFR_db_v1_2_1.xlsx", cl = 'AFR_calib_v1_2.xlsx', seed = 310123):
    ## Load projects and input parameters
    P =at.Project(framework=fw, databook=db, sim_start=1990, sim_end=2101, sim_dt=0.25, do_run=False) #test PSA on some parameters (vax eff, mtct_infx, mortality rates)

    cal = P.make_parset()
    cal.load_calibration(cl)

    np.random.seed(seed)
    afr_ua=P.parsets[0]

    parsets = {}
    results = {}

    ## Sample a set of parameters
    for i in range(1, n_samples+1):
        parsets[i] = afr_ua.sample()
    
    ## Copy the male treatment/vaccine parameters onto the female parameters
    ages = ['0-4', '5-14', '15-49', '50-69', '70+']
    trtinv = ['te_dc_cc', 'te_icl_ict', 'te_icl_cc', 'te_cc_dc', 'te_cc_hcc', 'te_ie_cc', 'te_m_dc', 'te_m_hcc', 'te_ict_hcc', 'te_ie_hcc', 'te_icl_hcc', 'te_dc_hcc']
    vacinv = ['eag_ve', 'sag_ve', 'hb3_ve', 'mav_ve']
    tot_pars = trtinv + vacinv

    for i in range(1, n_samples+1):
        for age in ages:
            for par in tot_pars:
                parsets[i].get_par(par).ts[f'{age}F'].assumption = parsets[i].get_par(par).ts[f'{age}M'].assumption
            
    ## Generate Results
    for i in range(1, n_samples+1):
        results[i] = P.run_sim(parsets[i], result_name = f'sample result {i}')
    
    return P, parsets, results

# %%
def input_results(n_samples, fw = 'hbv_v14_gamma_2.xlsx', db = "AFR_db_v1_2_1.xlsx", cl = 'AFR_calib_v1_2.xlsx', seed = 310123):

    ## Load projects and input parameters
    P, parsets, results = load_sto_project(n_samples, fw= fw, db=db, cl=cl, seed=seed)

    ages = ['0-4', '5-14', '15-49', '50-69', '70+']
    nathis = ['ci_p', 'm_acu', 'm_dc', 'm_hcc']
    trtinv = ['te_dc_cc', 'te_icl_ict', 'te_icl_cc', 'te_cc_dc', 'te_cc_hcc', 'te_ie_cc', 'te_m_dc', 'te_m_hcc', 'te_ict_hcc', 'te_ie_hcc', 'te_icl_hcc', 'te_dc_hcc']
    vacinv = ['eag_ve', 'sag_ve', 'hb3_ve', 'mav_ve']
    tot_pars = trtinv + vacinv

    ## Create a dataframe for the input parameters
    in_df = pd.DataFrame(columns = ['run_id']+nathis+trtinv+vacinv)

    for sim in range(1,n_samples+1):
        in_df.loc[sim,'run_id'] = sim
        for col in in_df.columns[1:]:
            in_df.loc[sim,col] = parsets[sim].get_par(col).ts[0].assumption #TODO: get different input parameters per population

    return in_df

# %%
def central_results(fw = 'hbv_v14_gamma_2.xlsx', db = "AFR_db_v1_2_1.xlsx", cl = 'AFR_calib_v1_2.xlsx'):
    P, res = load_cen_project(fw= fw, db=db, cl=cl)
    ## Locations for the important dataframes
    loc = 'Data/Templates/' # The location for the output templates may be different
    loc2 = 'Data/Demographics/' # The location for the input data may be different (depending on where you store it)
    
    ## Load and process the input data
    df1 = pd.read_csv(loc2+'202212rfp-1_dds-202208_int_pop_both.csv')
    
    df1 = df1[(df1.year >= 1990) & (df1.year <=2100)]
    age_groups = ['0-4', '5-14', '15-49', '50-69', '70+']

    for idx,row in df1.iterrows():
        if row.age_from < 5:
            df1.loc[idx,'age_group'] = '0-4'
        elif row.age_from < 15:
            df1.loc[idx,'age_group'] = '5-14'
        elif row.age_from < 50:
            df1.loc[idx,'age_group'] = '15-49'
        elif row.age_from < 70:
            df1.loc[idx,'age_group'] = '50-69'
        else:
            df1.loc[idx,'age_group'] = '70+'


    ## Start generating output results
    output_dict = {'cohort_size': 'alive', 'cases': 'tot_inc', 'dalys':'dalys'}
    cen_df = pd.read_csv(loc+'/central-burden-template.202212rfp-1.RFP_standard template_HepB.csv')

    for opt in output_dict:
        tot_val = res.get_variable(output_dict[opt])[0].vals + res.get_variable(output_dict[opt])[1].vals
        for age in range(0,5):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('0-4',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
                cen_df.loc[idx, opt] = ratio * res_val

        tot_val = res.get_variable(output_dict[opt])[2].vals + res.get_variable(output_dict[opt])[3].vals
        for age in range(5,15):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('5-14',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
                cen_df.loc[idx, opt] = ratio * res_val

        tot_val = res.get_variable(output_dict[opt])[4].vals + res.get_variable(output_dict[opt])[5].vals
        for age in range(15,50):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('15-49',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
                cen_df.loc[idx, opt] = ratio * res_val

        tot_val = res.get_variable(output_dict[opt])[6].vals + res.get_variable(output_dict[opt])[7].vals
        for age in range(50,70):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('50-69',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
                cen_df.loc[idx, opt] = ratio * res_val

        tot_val = res.get_variable(output_dict[opt])[8].vals + res.get_variable(output_dict[opt])[9].vals
        for age in range(70,101):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_from == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('70+',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
                cen_df.loc[idx, opt] = ratio * res_val
    
    ## Deaths are calculated separately
    tot_val = 0
    for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
        tot_val += res.get_variable(var)[0].vals + res.get_variable(var)[1].vals

    for age in range(0,5):
        for year in range(2000,2101):
            ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('0-4',year),'value']
            res_val = tot_val[(year-1990)*4]

            idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
            cen_df.loc[idx, 'deaths'] = ratio * res_val

    tot_val = 0
    for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
        tot_val += res.get_variable(var)[2].vals + res.get_variable(var)[3].vals
    for age in range(5,15):
        for year in range(2000,2101):
            ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('5-14',year),'value']
            res_val = tot_val[(year-1990)*4]

            idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
            cen_df.loc[idx, 'deaths'] = ratio * res_val

    tot_val = 0
    for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
        tot_val += res.get_variable(var)[4].vals + res.get_variable(var)[5].vals
    for age in range(15,50):
        for year in range(2000,2101):
            ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('15-49',year),'value']
            res_val = tot_val[(year-1990)*4]

            idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
            cen_df.loc[idx, 'deaths'] = ratio * res_val

    tot_val = 0
    for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
        tot_val += res.get_variable(var)[6].vals + res.get_variable(var)[7].vals
    for age in range(50,70):
        for year in range(2000,2101):
            ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('50-69',year),'value']
            res_val = tot_val[(year-1990)*4]

            idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
            cen_df.loc[idx, 'deaths'] = ratio * res_val

    tot_val = 0
    for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
        tot_val += res.get_variable(var)[8].vals + res.get_variable(var)[9].vals
    for age in range(70,101):
        for year in range(2000,2101):
            ratio = float(df1[(df1.age_from == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('70+',year),'value']
            res_val = tot_val[(year-1990)*4]

            idx = cen_df[(cen_df.year == year) & (cen_df.age == age)].index[0]
            cen_df.loc[idx, 'deaths'] = ratio * res_val

    return cen_df

# %%
def stochastic_results(n_samples, fw = 'hbv_v14_gamma_2.xlsx', db = "AFR_db_v1_2_1.xlsx", cl = 'AFR_calib_v1_2.xlsx', seed = 310123):
    
    P, parsets, results = load_sto_project(n_samples, fw= fw, db=db, cl=cl, seed=seed)
    ## TODO: load project for stochastic results
    
    ## Locations for the important dataframes
    loc = 'Data/Templates/' # The location for the output templates may be different
    loc2 = 'Data/Demographics/' # The location for the input data may be different (depending on where you store it)
    
    df = pd.read_csv(loc+'/stochastic-burden-template.202212rfp-1.RFP_standard template_HepB.csv') #template
    
     ## Load and process the input data
    df1 = pd.read_csv(loc2+'202212rfp-1_dds-202208_int_pop_both.csv')

    df1 = df1[(df1.year >= 1990) & (df1.year <=2100)]
    age_groups = ['0-4', '5-14', '15-49', '50-69', '70+']

    for idx,row in df1.iterrows():
        if row.age_from < 5:
            df1.loc[idx,'age_group'] = '0-4'
        elif row.age_from < 15:
            df1.loc[idx,'age_group'] = '5-14'
        elif row.age_from < 50:
            df1.loc[idx,'age_group'] = '15-49'
        elif row.age_from < 70:
            df1.loc[idx,'age_group'] = '50-69'
        else:
            df1.loc[idx,'age_group'] = '70+'
    
    dfs = {}
    output_dict = {'cohort_size': 'alive', 'cases': 'tot_inc', 'dalys':'dalys'}
    for sim in range(1,n_samples+1):
        stores = results[sim]
        print(f'Sim no {sim}')

        dfs[sim] = pd.read_csv(loc+'/stochastic-burden-template.202212rfp-1.RFP_standard template_HepB.csv')
        dfs[sim].run_id = sim
        ## Other outputs
        for opt in output_dict:
            print(opt)
            tot_val = stores.get_variable(output_dict[opt])[0].vals + stores.get_variable(output_dict[opt])[1].vals
            for age in range(0,5):
                for year in range(2000,2101):
                    ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('0-4',year),'value']
                    res_val = tot_val[(year-1990)*4]

                    idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                    dfs[sim].loc[idx, opt] = ratio * res_val

            tot_val = stores.get_variable(output_dict[opt])[2].vals + stores.get_variable(output_dict[opt])[3].vals
            for age in range(5,15):
                for year in range(2000,2101):
                    ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('5-14',year),'value']
                    res_val = tot_val[(year-1990)*4]

                    idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                    dfs[sim].loc[idx, opt] = ratio * res_val

            tot_val = stores.get_variable(output_dict[opt])[4].vals + stores.get_variable(output_dict[opt])[5].vals
            for age in range(15,50):
                for year in range(2000,2101):
                    ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('15-49',year),'value']
                    res_val = tot_val[(year-1990)*4]

                    idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                    dfs[sim].loc[idx, opt] = ratio * res_val

            tot_val = stores.get_variable(output_dict[opt])[6].vals + stores.get_variable(output_dict[opt])[7].vals
            for age in range(50,70):
                for year in range(2000,2101):
                    ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('50-69',year),'value']
                    res_val = tot_val[(year-1990)*4]

                    idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                    dfs[sim].loc[idx, opt] = ratio * res_val

            tot_val = stores.get_variable(output_dict[opt])[8].vals + stores.get_variable(output_dict[opt])[9].vals
            for age in range(70,101):
                for year in range(2000,2101):
                    ratio = float(df1[(df1.age_from == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('70+',year),'value']
                    res_val = tot_val[(year-1990)*4]

                    idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                    dfs[sim].loc[idx, opt] = ratio * res_val

        ## Deaths
        tot_val = 0
        for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
            tot_val += stores.get_variable(var)[0].vals + stores.get_variable(var)[1].vals

        for age in range(0,5):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('0-4',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                dfs[sim].loc[idx, 'deaths'] = ratio * res_val

        tot_val = 0
        for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
            tot_val += stores.get_variable(var)[2].vals + stores.get_variable(var)[3].vals
        for age in range(5,15):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('5-14',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                dfs[sim].loc[idx, 'deaths'] = ratio * res_val

        tot_val = 0
        for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
            tot_val += stores.get_variable(var)[4].vals + stores.get_variable(var)[5].vals
        for age in range(15,50):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('15-49',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                dfs[sim].loc[idx, 'deaths'] = ratio * res_val

        tot_val = 0
        for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
            tot_val += stores.get_variable(var)[6].vals + stores.get_variable(var)[7].vals
        for age in range(50,70):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_to == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('50-69',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                dfs[sim].loc[idx, 'deaths'] = ratio * res_val

        tot_val = 0
        for var in ['cl_acu', 'cl_cir', 'cl_hcc']:
            tot_val += stores.get_variable(var)[8].vals + stores.get_variable(var)[9].vals
        for age in range(70,101):
            for year in range(2000,2101):
                ratio = float(df1[(df1.age_from == age) & (df1.year == year)].value)/df1.groupby(by=['age_group','year']).sum().loc[('70+',year),'value']
                res_val = tot_val[(year-1990)*4]

                idx = df[(dfs[sim].year == year) & (dfs[sim].age == age)].index[0]
                dfs[sim].loc[idx, 'deaths'] = ratio * res_val

    final_df = dfs[1]
    for i in range(2,n_samples+1):
        final_df = pd.concat([final_df,dfs[i]])

    return final_df

# %%
n_samples = 30
fw = 'hbv_v14_gamma_2.xlsx' 
db_n = "AFR_db_v1_2_1_no_vax.xlsx"
db_v = "AFR_db_v1_2_1.xlsx"
cl = 'AFR_calib_v1_2.xlsx' 
seed = 310123

# %% [markdown]
# ## Generate no-vax results

# %%
in_df_n = input_results(30, db = db_n)
# Out:
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.55s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.45s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.61s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.64s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.45s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.48s
# Elapsed time for running "default": 1.48s
# Elapsed time for running "default": 1.48s
# Elapsed time for running "default": 1.66s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.45s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.44s

# %%
in_df_n.to_csv('input_results_novax.csv', index = False)

# %%
cen_df_n = central_results(db = db_n)
# Out:
# Elapsed time for running "default": 1.44s

# %%
cen_df_n.to_csv('central_results_novax.csv', index = False)

# %%
final_df_n = stochastic_results(30, db = db_n)
# Out:
# Elapsed time for running "default": 1.39s
# Elapsed time for running "default": 1.51s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.55s
# Elapsed time for running "default": 1.38s
# Elapsed time for running "default": 1.40s
# Elapsed time for running "default": 1.40s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.39s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.54s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.40s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.60s
# Elapsed time for running "default": 1.39s
# Elapsed time for running "default": 1.45s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.41s
# Sim no 1
# cohort_size
# cases
# dalys
# Sim no 2
# cohort_size
# cases
# dalys
# Sim no 3
# cohort_size
# cases
# dalys
# Sim no 4
# cohort_size
# cases
# dalys
# Sim no 5
# cohort_size
# cases
# dalys
# Sim no 6
# cohort_size
# cases
# dalys
# Sim no 7
# cohort_size
# cases
# dalys
# Sim no 8
# cohort_size
# cases
# dalys
# Sim no 9
# cohort_size
# cases
# dalys
# Sim no 10
# cohort_size
# cases
# dalys
# Sim no 11
# cohort_size
# cases
# dalys
# Sim no 12
# cohort_size
# cases
# dalys
# Sim no 13
# cohort_size
# cases
# dalys
# Sim no 14
# cohort_size
# cases
# dalys
# Sim no 15
# cohort_size
# cases
# dalys
# Sim no 16
# cohort_size
# cases
# dalys
# Sim no 17
# cohort_size
# cases
# dalys
# Sim no 18
# cohort_size
# cases
# dalys
# Sim no 19
# cohort_size
# cases
# dalys
# Sim no 20
# cohort_size
# cases
# dalys
# Sim no 21
# cohort_size
# cases
# dalys
# Sim no 22
# cohort_size
# cases
# dalys
# Sim no 23
# cohort_size
# cases
# dalys
# Sim no 24
# cohort_size
# cases
# dalys
# Sim no 25
# cohort_size
# cases
# dalys
# Sim no 26
# cohort_size
# cases
# dalys
# Sim no 27
# cohort_size
# cases
# dalys
# Sim no 28
# cohort_size
# cases
# dalys
# Sim no 29
# cohort_size
# cases
# dalys
# Sim no 30
# cohort_size
# cases
# dalys

# %%
final_df_n.to_csv('stochastic_results_novax.csv', index = False)

# %% [markdown]
# ## Generate vax results

# %%
in_df_v = input_results(30, db = db_v)
# Out:
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.45s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.53s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.45s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.58s
# Elapsed time for running "default": 1.48s
# Elapsed time for running "default": 1.49s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.67s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.46s
# Elapsed time for running "default": 1.47s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.45s

# %%
in_df_v.to_csv('input_results_vax.csv', index = False)

# %%
cen_df_v = central_results(db = db_v)
# Out:
# Elapsed time for running "default": 1.38s

# %%
cen_df_v.to_csv('central_results_vax.csv', index = False)

# %%
final_df_v = stochastic_results(30, db = db_v)
# Out:
# Elapsed time for running "default": 1.49s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.50s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.45s
# Elapsed time for running "default": 1.45s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.40s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.54s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.44s
# Elapsed time for running "default": 1.40s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.57s
# Elapsed time for running "default": 1.40s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.41s
# Elapsed time for running "default": 1.43s
# Elapsed time for running "default": 1.42s
# Elapsed time for running "default": 1.39s
# Sim no 1
# cohort_size
# cases
# dalys
# Sim no 2
# cohort_size
# cases
# dalys
# Sim no 3
# cohort_size
# cases
# dalys
# Sim no 4
# cohort_size
# cases
# dalys
# Sim no 5
# cohort_size
# cases
# dalys
# Sim no 6
# cohort_size
# cases
# dalys
# Sim no 7
# cohort_size
# cases
# dalys
# Sim no 8
# cohort_size
# cases
# dalys
# Sim no 9
# cohort_size
# cases
# dalys
# Sim no 10
# cohort_size
# cases
# dalys
# Sim no 11
# cohort_size
# cases
# dalys
# Sim no 12
# cohort_size
# cases
# dalys
# Sim no 13
# cohort_size
# cases
# dalys
# Sim no 14
# cohort_size
# cases
# dalys
# Sim no 15
# cohort_size
# cases
# dalys
# Sim no 16
# cohort_size
# cases
# dalys
# Sim no 17
# cohort_size
# cases
# dalys
# Sim no 18
# cohort_size
# cases
# dalys
# Sim no 19
# cohort_size
# cases
# dalys
# Sim no 20
# cohort_size
# cases
# dalys
# Sim no 21
# cohort_size
# cases
# dalys
# Sim no 22
# cohort_size
# cases
# dalys
# Sim no 23
# cohort_size
# cases
# dalys
# Sim no 24
# cohort_size
# cases
# dalys
# Sim no 25
# cohort_size
# cases
# dalys
# Sim no 26
# cohort_size
# cases
# dalys
# Sim no 27
# cohort_size
# cases
# dalys
# Sim no 28
# cohort_size
# cases
# dalys
# Sim no 29
# cohort_size
# cases
# dalys
# Sim no 30
# cohort_size
# cases
# dalys

# %%
final_df_v.to_csv('stochastic_results_vax.csv', index = False)

# %% [markdown]
# ## Plot results

# %%
import matplotlib.pyplot as plt

# %%
np.arange(1,8)
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
final_df_v.columns
# Out:
# Index(['disease', 'run_id', 'year', 'age', 'country', 'country_name',
#        'cohort_size', 'cases', 'dalys', 'deaths'],
#       dtype='object')

# %% [markdown]
# ### Functions

# %%
def plot_output(df, age, run_id, output):
    plt.plot(np.arange(2000,2101), df[(df.age == age) & (df.run_id == run_id)][output])

# %%
def plot_cen_output(df, age, output):
    plt.plot(np.arange(2000,2101), df[(df.age == age)][output],color = 'black',linewidth=2)

# %%
def plot_all(cen_df, sto_df, age):
    plt.figure()
    for i in range(1,31):
        plot_output(sto_df, age, i, 'cohort_size')
        plot_cen_output(cen_df, age, 'cohort_size')

    plt.figure()
    for i in range(1,31):
        plot_output(sto_df, age, i, 'cases')
        plot_cen_output(cen_df, age, 'cases')

    plt.figure()
    for i in range(1,31):
        plot_output(sto_df, age, i, 'dalys')
        plot_cen_output(cen_df, age, 'dalys')
        

    plt.figure()
    for i in range(1,31):
        plot_output(sto_df, age, i, 'deaths')
        plot_cen_output(cen_df, age, 'deaths')

# %% [markdown]
# ### Find a way to create plots similar to the ensemble plots

# %%
for i in range(1,31):
    plot_output(final_df_v, 30, i, 'cohort_size')

# %%
for i in range(1,31):
    plot_output(final_df_v, 30, i, 'cases')

# %%
for i in range(1,31):
    plot_output(final_df_v, 30, i, 'deaths')

# %%
for i in range(1,31):
    plot_output(final_df_v, 30, i, 'dalys')

# %% [markdown]
# ### Stochastic Results (vax)

# %%
age = 1
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cohort_size')
    plot_cen_output(cen_df_v, age, 'cohort_size')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cases')
    plot_cen_output(cen_df_v, age, 'cases')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'dalys')
    plot_cen_output(cen_df_v, age, 'dalys')
    

plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'deaths')
    plot_cen_output(cen_df_v, age, 'deaths')

# %%
age = 10
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cohort_size')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cases')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'dalys')

plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'deaths')

# %%
age = 30
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cohort_size')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cases')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'dalys')

plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'deaths')

# %%
age = 60
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cohort_size')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cases')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'dalys')

plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'deaths')

# %%
age = 80
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cohort_size')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'cases')
    
plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'dalys')

plt.figure()
for i in range(1,31):
    plot_output(final_df_v, age, i, 'deaths')

# %%
i
# Out:
# 1

# %%
final_df_v
# Out:
#       disease  run_id  year  age country          country_name   cohort_size  \
# 0        HepB       1  2000    0     RFP  Request for Proposal  4.788467e+06
# 1        HepB       1  2001    0     RFP  Request for Proposal  4.942015e+06
# 2        HepB       1  2002    0     RFP  Request for Proposal  5.086198e+06
# 3        HepB       1  2003    0     RFP  Request for Proposal  5.218905e+06
# 4        HepB       1  2004    0     RFP  Request for Proposal  5.339088e+06
# ...       ...     ...   ...  ...     ...                   ...           ...
# 10196    HepB      30  2096  100     RFP  Request for Proposal  4.667900e+03
# 10197    HepB      30  2097  100     RFP  Request for Proposal  4.890242e+03
# 10198    HepB      30  2098  100     RFP  Request for Proposal  5.116621e+03
# 10199    HepB      30  2099  100     RFP  Request for Proposal  5.373128e+03
# 10200    HepB      30  2100  100     RFP  Request for Proposal  5.672327e+03
#
#               cases        dalys     deaths
# 0      62672.254450  7955.273538  67.311074
# 1      64572.794634  8199.959912  69.305423
# 2      66274.820083  8428.889246  71.164755
# 3      67715.560863  8640.196626  72.876628
# 4      68949.980174  8834.103540  74.445323
# ...             ...          ...        ...
# 10196      0.011548     9.472805   0.984408
# 10197      0.011538     9.662500   1.005122
# 10198      0.011514     9.841832   1.024747
# 10199      0.011536    10.059362   1.048397
# 10200      0.011620    10.345027   1.078193
#
# [316231 rows x 10 columns]

# %%
len(final_df_v[(final_df_v.age == 0) & (final_df_v.run_id == 1)].cohort_size)
# Out:
# 202

# %% [markdown]
# ### Results (no vax)

# %%
cen_df_n
# Out:
#       disease  year  age country          country_name   cohort_size  \
# 0        HepB  2000    0     RFP  Request for Proposal  4.788461e+06
# 1        HepB  2001    0     RFP  Request for Proposal  4.942008e+06
# 2        HepB  2002    0     RFP  Request for Proposal  5.086190e+06
# 3        HepB  2003    0     RFP  Request for Proposal  5.218897e+06
# 4        HepB  2004    0     RFP  Request for Proposal  5.339080e+06
# ...       ...   ...  ...     ...                   ...           ...
# 10196    HepB  2096  100     RFP  Request for Proposal  4.634937e+03
# 10197    HepB  2097  100     RFP  Request for Proposal  4.855076e+03
# 10198    HepB  2098  100     RFP  Request for Proposal  5.079174e+03
# 10199    HepB  2099  100     RFP  Request for Proposal  5.333129e+03
# 10200    HepB  2100  100     RFP  Request for Proposal  5.629393e+03
#
#               cases        dalys     deaths
# 0      63591.399047  8094.338423  69.299642
# 1      65539.111059  8347.905886  71.394088
# 2      67284.998527  8585.458422  73.349536
# 3      68764.728781  8805.030188  75.152453
# 4      70034.244181  9006.785996  76.806950
# ...             ...          ...        ...
# 10196      0.243048    31.100835   3.136793
# 10197      0.253345    32.440810   3.275187
# 10198      0.263795    33.791552   3.414746
# 10199      0.275729    35.322491   3.572794
# 10200      0.289715    37.149341   3.757708
#
# [10201 rows x 9 columns]

# %%
plot_all(cen_df_n, final_df_n, 1)

# %%
plot_all(cen_df_n, final_df_n, 10)

# %%
plot_all(cen_df_n, final_df_n, 30)

# %%
plot_all(cen_df_n, final_df_n, 60)

# %%
plot_all(cen_df_n, final_df_n, 80)

# %% [markdown]
# ### Results (vax)

# %%
cen_df_n
# Out:
#       disease  year  age country          country_name   cohort_size  \
# 0        HepB  2000    0     RFP  Request for Proposal  4.788461e+06
# 1        HepB  2001    0     RFP  Request for Proposal  4.942008e+06
# 2        HepB  2002    0     RFP  Request for Proposal  5.086190e+06
# 3        HepB  2003    0     RFP  Request for Proposal  5.218897e+06
# 4        HepB  2004    0     RFP  Request for Proposal  5.339080e+06
# ...       ...   ...  ...     ...                   ...           ...
# 10196    HepB  2096  100     RFP  Request for Proposal  4.634937e+03
# 10197    HepB  2097  100     RFP  Request for Proposal  4.855076e+03
# 10198    HepB  2098  100     RFP  Request for Proposal  5.079174e+03
# 10199    HepB  2099  100     RFP  Request for Proposal  5.333129e+03
# 10200    HepB  2100  100     RFP  Request for Proposal  5.629393e+03
#
#               cases        dalys     deaths
# 0      63591.399047  8094.338423  69.299642
# 1      65539.111059  8347.905886  71.394088
# 2      67284.998527  8585.458422  73.349536
# 3      68764.728781  8805.030188  75.152453
# 4      70034.244181  9006.785996  76.806950
# ...             ...          ...        ...
# 10196      0.243048    31.100835   3.136793
# 10197      0.253345    32.440810   3.275187
# 10198      0.263795    33.791552   3.414746
# 10199      0.275729    35.322491   3.572794
# 10200      0.289715    37.149341   3.757708
#
# [10201 rows x 9 columns]

# %%
plot_all(cen_df_v, final_df_v, 1)

# %%
plot_all(cen_df_v, final_df_v, 10)

# %%
plot_all(cen_df_v, final_df_v, 30)

# %%
plot_all(cen_df_v, final_df_v, 60)

# %%
plot_all(cen_df_v, final_df_v, 80)

# %% [markdown]
# ## TODO:
# - compare these plots with data (scaled to population or prevalence)
# - input parameter plots (box plots)
# -

# %%
in_df_n.columns
# Out:
# 'ci_p'

# %%
nathis = ['ci_p', 'm_acu', 'm_dc', 'm_hcc']
trtinv = ['te_dc_cc', 'te_icl_ict', 'te_icl_cc', 'te_cc_dc', 'te_cc_hcc', 'te_ie_cc', 'te_m_dc', 'te_m_hcc', 'te_ict_hcc', 'te_ie_hcc', 'te_icl_hcc', 'te_dc_hcc']
vacinv = ['eag_ve', 'sag_ve', 'hb3_ve', 'mav_ve']

# %%
'ci_p' in in_df_n.columns
# Out:
# True

# %%
in_df_n.dtypes
# Out:
# run_id        object
# ci_p          object
# m_acu         object
# m_dc          object
# m_hcc         object
# te_dc_cc      object
# te_icl_ict    object
# te_icl_cc     object
# te_cc_dc      object
# te_cc_hcc     object
# te_ie_cc      object
# te_m_dc       object
# te_m_hcc      object
# te_ict_hcc    object
# te_ie_hcc     object
# te_icl_hcc    object
# te_dc_hcc     object
# eag_ve        object
# sag_ve        object
# hb3_ve        object
# mav_ve        object
# dtype: object

# %%
boxplot=in_df_n.boxplot(column = ['ci_p'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27852/2656814471.py in <module>
# ----> 1 boxplot=in_df_n.boxplot(column = ['ci_p'])
#
# ~\miniconda3\envs\torch\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     520         layout=layout,
#     521         return_type=return_type,
# --> 522         **kwargs,
#     523     )
#     524
#
# ~\miniconda3\envs\torch\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     403         layout=layout,
#     404         return_type=return_type,
# --> 405         **kwds,
#     406     )
#     407     plt.draw_if_interactive()
#
# ~\miniconda3\envs\torch\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     369             columns = data.columns
#     370         else:
# --> 371             data = data[columns]
#     372
#     373         result = plot_group(columns, data.values.T, ax)
#
# ~\miniconda3\envs\torch\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\miniconda3\envs\torch\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\miniconda3\envs\torch\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['ci_p'], dtype='object')] are in the [columns]"

# %%
df.columns
# Out:
# Index(['Col1', 'Col2', 'Col3', 'Col4'], dtype='object')

# %%
np.random.seed(1234)
df = pd.DataFrame(np.random.randn(10, 4),
                  columns=['Col1', 'Col2', 'Col3', 'Col4'])
boxplot = df.boxplot(column=['Col1', 'Col2', 'Col3'])
